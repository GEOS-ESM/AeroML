# %%
from g5nr import G5NR_QC, Meta, Target, Features

x = G5NR_QC()
# Out:
# any valid? True

# %%
print("Angles")
x.toDataFrame(Vars=['GlintAngle', 'ScatteringAngle']).describe()
# Out:
# Angles
#        GlintAngle.01  GlintAngle.02  GlintAngle.03  GlintAngle.04  \
# count  119319.000000  119319.000000  119319.000000  119319.000000
# mean       71.544453      61.875957      54.977337      50.303466
# std        36.192691      31.541567      26.196854      21.116291
# min        18.915581      19.725491      20.059505      19.945492
# 25%        36.282488      33.083574      32.962702      32.487415
# 50%        68.415375      54.793987      46.367676      46.126343
# 75%       103.615860      89.361618      76.233078      63.625727
# max       140.152237     125.963890     112.513069      99.319435
#
#        GlintAngle.05  GlintAngle.06  GlintAngle.07  GlintAngle.08  \
# count  119319.000000  119319.000000  119319.000000  119319.000000
# mean       47.733824      47.237594      48.876446      52.777343
# std        17.854989      18.082156      21.674188      26.923701
# min        19.435884      18.623972      17.704878      16.841919
# ...

# %%
x.toDataFrame(Vars=Features).describe()
# Out:
#            Ref360.01      Ref360.02      Ref360.03      Ref360.04  \
# count  119319.000000  119319.000000  119319.000000  119319.000000
# mean        0.444316       0.337449       0.282507       0.252899
# std         0.179688       0.113363       0.076486       0.054116
# min         0.150440       0.121937       0.113870       0.116136
# 25%         0.291915       0.241992       0.221418       0.217159
# 50%         0.384377       0.304822       0.261890       0.238836
# 75%         0.561631       0.410931       0.327210       0.276680
# max         1.095492       0.865805       0.774479       0.780875
#
#            Ref360.05      Ref360.06      Ref360.07      Ref360.08  \
# count  119319.000000  119319.000000  119319.000000  119319.000000
# mean        0.239551       0.239149       0.251544       0.279804
# std         0.044252       0.046906       0.059805       0.082253
# min         0.118880       0.125543       0.118209       0.117679
# ...

# %%
x.toDataFrame(Vars=Target).describe()
# Out:
#               Tau355         Tau440         Tau550         Tau870
# count  119319.000000  119319.000000  119319.000000  119319.000000
# mean        0.128907       0.115989       0.103426       0.083548
# std         0.173226       0.157540       0.145770       0.135476
# min         0.005513       0.004442       0.003446       0.001775
# 25%         0.047127       0.041284       0.035376       0.025224
# 50%         0.078872       0.070161       0.061093       0.045713
# 75%         0.138131       0.124323       0.110088       0.085959
# max         5.926248       5.519411       5.545711       5.545196
